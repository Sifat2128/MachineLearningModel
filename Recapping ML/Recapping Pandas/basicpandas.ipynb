# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df4 = pd.DataFrame({
    'Roll' : [2203098 , 2203122 , 2203132],
    'Name' : ['sifat','sejuti','lamia'],
    'CGPA' : [3.44,3.76,3.86]
})

# %%
df2 = pd.DataFrame([[2203098,2203122,2203132],["sifat","sejuti","lamia"],
                   [3.44,3.76,3.86]], columns = ['Roll','Name','CGPA'])

# %%
arr = np.array([[1, 2], [3, 4]])
df3 = pd.DataFrame(arr, columns=['A', 'B'])

# %%
df = pd.read_csv('Iris.csv',index_col= 0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
df.info()
df.describe()
df.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# ...

# %%
df.dtypes
df.columns
df.index
df.tail(5)
df.sample(5)
df.memory_usage() #memory usage per column
# Out:
# Index            1200
# SepalLengthCm    1200
# SepalWidthCm     1200
# PetalLengthCm    1200
# PetalWidthCm     1200
# Species          1200
# dtype: int64

# %% [markdown]
# 3.Selection and Indexing

# %%
df['Id']
df[['Id','SepalLengthCm']]
# Out:
#       Id  SepalLengthCm
# 0      1            5.1
# 1      2            4.9
# 2      3            4.7
# 3      4            4.6
# 4      5            5.0
# ..   ...            ...
# 145  146            6.7
# 146  147            6.3
# 147  148            6.5
# 148  149            6.2
# 149  150            5.9
#
# [150 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object

# %%
df.iloc[:,0:3]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm
# Id
# 1              5.1           3.5            1.4
# 2              4.9           3.0            1.4
# 3              4.7           3.2            1.3
# 4              4.6           3.1            1.5
# 5              5.0           3.6            1.4
# ..             ...           ...            ...
# 146            6.7           3.0            5.2
# 147            6.3           2.5            5.0
# 148            6.5           3.0            5.2
# 149            6.2           3.4            5.4
# 150            5.9           3.0            5.1
#
# [150 rows x 3 columns]

# %%
df.iloc[0:3,0:2]
# Out:
#     SepalLengthCm  SepalWidthCm
# Id
# 1             5.1           3.5
# 2             4.9           3.0
# 3             4.7           3.2

# %%
df.loc[1]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object

# %%
df[df['SepalLengthCm'].isin([1,2,4,5])]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# Id
# 5             5.0           3.6            1.4           0.2      Iris-setosa
# 8             5.0           3.4            1.5           0.2      Iris-setosa
# 26            5.0           3.0            1.6           0.2      Iris-setosa
# 27            5.0           3.4            1.6           0.4      Iris-setosa
# 36            5.0           3.2            1.2           0.2      Iris-setosa
# 41            5.0           3.5            1.3           0.3      Iris-setosa
# 44            5.0           3.5            1.6           0.6      Iris-setosa
# 50            5.0           3.3            1.4           0.2      Iris-setosa
# 61            5.0           2.0            3.5           1.0  Iris-versicolor
# 94            5.0           2.3            3.3           1.0  Iris-versicolor
